# %%
name = '김현아'
age = 30

# %%
print(name,age)
# Out:
# 김현아 30

# %%
# 변수와 객체
# 변수명 = 데이터(객체)
name = "김현아" # 문자형 데이터 -> " "
age = 30 # 정수형 데이터

# %%
print(name)
print(age)
# Out:
# 김현아
# 30

# %%
# 변수 삭제
del(age)

# %%
# print(age)

# %%
name = "김현아"
age = 30
adderess = "대한민국 대구"
phone = "010123456789" # 번호체계 : 국가/ 지역/ 연산 x > 문자형 데이터
market_T_F = True

# %%
# 객체 출력
print(name, age, adderess, phone, market_T_F)
# Out:
# 김현아 30 대한민국 대구 010123456789 True

# %%
# 기본자료형
# 변수의 유형 확인 : type()
a = 1
print(type(a))
b = 1.0
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
# 숫자형 데이터의 연산
c = a + b
print(c, type(c))
# Out:
# 2.0 <class 'float'>

# %%
c = int(a+b)
print(c,type(c))
# Out:
# 2 <class 'int'>

# %%
a = 10
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a**b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 14
# 6
# 40
# 10000
# 2.5
# 2
# 2

# %%
# 논리 연산 : True/False
a = 10
b = 4
print(a == b)
print(a != b)
print(a > b)
print(a < b)
# Out:
# False
# True
# True
# False

# %%
# 논리형
a = True
b = "True"

print(a, type(a))
print(b, type(b))
# Out:
# True <class 'bool'>
# True <class 'str'>

# %%
print(True)
print(False)
print(1==1)
print(type(1==1))
print(float(1==1))
print(float(1>3))
# Out:
# True
# False
# True
# <class 'bool'>
# 1.0
# 0.0

# %%
name = "김현아"
print(name, type(name))
# Out:
# 김현아 <class 'str'>

# %%
a = "Hi "
b = "My name is "
c = "hyun a"
print(a+b+c)
# Out:
# Hi My name is hyun a

# %%
a = "hi"
print(a*3)
# Out:
# hihihi

# %%
# 문자형 데이터 메소드(함수)
a = "Hi My name is hyuna"

print(len(a))
print(a.count('n'))
print(a.find('n')) # 지정한 문자의 인덱스 값
print(a.upper())
print(a.lower())
# Out:
# 19
# 2
# 6
# HI MY NAME IS HYUNA
# hi my name is hyuna

# %%
a = " Hi My name is hyuna "
print(len(a))
print(a.strip())
print(a.lstrip())
print(a.rstrip())
# Out:
# 21
# Hi My name is hyuna
# Hi My name is hyuna
#  Hi My name is hyuna

# %%
a = "Hi, My name is hyuna"
print(a.replace('hyuna','mingi'))
print(a.split())
print(a.split(','))
# Out:
# Hi, My name is mingi
# ['Hi,', 'My', 'name', 'is', 'hyuna']
# ['Hi', ' My name is hyuna']
